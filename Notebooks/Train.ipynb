# %%
import sys
sys.path.append('../Scripts/')
sys.path.append('../models/')
import matplotlib.pyplot as plt

# %%
from dataloader import *
from CornerNet import *

# %% [markdown]
# ## Check Dataloader

# %%
data = SpineDataset()
dataloader = torch.utils.data.DataLoader(data, batch_size=2)

# %%
sample = data.__getitem__(0)

# %%
sample['ys'][0].shape
# Out:
# torch.Size([1, 384, 128])

# %%
plt.imshow(sample['ys'][0][0])

# %%
plt.imshow(sample['ys'][1][0])

# %%
plt.imshow(sample['ys'][2][0])

# %%
plt.imshow(sample['ys'][3][0])

# %%
plt.imshow(sample['xs'][0].permute(1,2,0))

# %% [markdown]
# ## Check Model

# %%
# del model
model = model()

# %%
for sample in dataloader:
    out = model(*sample['xs'])
    break

# %%
loss = loss(out, sample['ys'])
# Out:
# /opt/conda/conda-bld/pytorch_1591914880026/work/aten/src/ATen/native/IndexingUtils.h:20: UserWarning: indexing with dtype torch.uint8 is now deprecated, please use a dtype torch.bool instead.
# /opt/conda/conda-bld/pytorch_1591914880026/work/aten/src/ATen/native/IndexingUtils.h:20: UserWarning: indexing with dtype torch.uint8 is now deprecated, please use a dtype torch.bool instead.
# /opt/conda/conda-bld/pytorch_1591914880026/work/aten/src/ATen/native/IndexingUtils.h:20: UserWarning: indexing with dtype torch.uint8 is now deprecated, please use a dtype torch.bool instead.
# /opt/conda/conda-bld/pytorch_1591914880026/work/aten/src/ATen/native/IndexingUtils.h:20: UserWarning: indexing with dtype torch.uint8 is now deprecated, please use a dtype torch.bool instead.
# /opt/conda/conda-bld/pytorch_1591914880026/work/aten/src/ATen/native/IndexingUtils.h:20: UserWarning: indexing with dtype torch.uint8 is now deprecated, please use a dtype torch.bool instead.
# /opt/conda/conda-bld/pytorch_1591914880026/work/aten/src/ATen/native/IndexingUtils.h:20: UserWarning: indexing with dtype torch.uint8 is now deprecated, please use a dtype torch.bool instead.
# /opt/conda/conda-bld/pytorch_1591914880026/work/aten/src/ATen/native/IndexingUtils.h:20: UserWarning: indexing with dtype torch.uint8 is now deprecated, please use a dtype torch.bool instead.
# /opt/conda/conda-bld/pytorch_1591914880026/work/aten/src/ATen/native/IndexingUtils.h:20: UserWarning: indexing with dtype torch.uint8 is now deprecated, please use a dtype torch.bool instead.
# /opt/conda/conda-bld/pytorch_1591914880026/work/aten/src/ATen/native/IndexingUtils.h:20: UserWarning: indexing with dtype torch.uint8 is now deprecated, please use a dtype torch.bool instead.
# /opt/conda/conda-bld/pytorch_1591914880026/work/aten/src/ATen/native/IndexingUtils.h:20: UserWarning: indexing with dtype torch.uint8 is now deprecated, please use a dtype torch.bool instead.
# /home/rajat/anaconda3/lib/python3.7/site-packages/torch/nn/_reduction.py:43: UserWarning: size_average and reduce args will be deprecated, please use reduction='sum' instead.
#   warnings.warn(warning.format(ret))
# /opt/conda/conda-bld/pytorch_1591914880026/work/aten/src/ATen/native/IndexingUtils.h:20: UserWarning: indexing with dtype torch.uint8 is now deprecated, please use a dtype torch.bool instead.
# /opt/conda/conda-bld/pytorch_1591914880026/work/aten/src/ATen/native/IndexingUtils.h:20: UserWarning: indexing with dtype torch.uint8 is now deprecated, please use a dtype torch.bool instead.
# /opt/conda/conda-bld/pytorch_1591914880026/work/aten/src/ATen/native/IndexingUtils.h:20: UserWarning: indexing with dtype torch.uint8 is now deprecated, please use a dtype torch.bool instead.
# /opt/conda/conda-bld/pytorch_1591914880026/work/aten/src/ATen/native/IndexingUtils.h:20: UserWarning: indexing with dtype torch.uint8 is now deprecated, please use a dtype torch.bool instead.
# /opt/conda/conda-bld/pytorch_1591914880026/work/aten/src/ATen/native/IndexingUtils.h:20: UserWarning: indexing with dtype torch.uint8 is now deprecated, please use a dtype torch.bool instead.
# /opt/conda/conda-bld/pytorch_1591914880026/work/aten/src/ATen/native/IndexingUtils.h:20: UserWarning: indexing with dtype torch.uint8 is now deprecated, please use a dtype torch.bool instead.
# /opt/conda/conda-bld/pytorch_1591914880026/work/aten/src/ATen/native/IndexingUtils.h:20: UserWarning: indexing with dtype torch.uint8 is now deprecated, please use a dtype torch.bool instead.
# /opt/conda/conda-bld/pytorch_1591914880026/work/aten/src/ATen/native/IndexingUtils.h:20: UserWarning: indexing with dtype torch.uint8 is now deprecated, please use a dtype torch.bool instead.
# /opt/conda/conda-bld/pytorch_1591914880026/work/aten/src/ATen/native/IndexingUtils.h:20: UserWarning: indexing with dtype torch.uint8 is now deprecated, please use a dtype torch.bool instead.
# /opt/conda/conda-bld/pytorch_1591914880026/work/aten/src/ATen/native/IndexingUtils.h:20: UserWarning: indexing with dtype torch.uint8 is now deprecated, please use a dtype torch.bool instead.
# /opt/conda/conda-bld/pytorch_1591914880026/work/aten/src/ATen/native/IndexingUtils.h:20: UserWarning: indexing with dtype torch.uint8 is now deprecated, please use a dtype torch.bool instead.
# /opt/conda/conda-bld/pytorch_1591914880026/work/aten/src/ATen/native/IndexingUtils.h:20: UserWarning: indexing with dtype torch.uint8 is now deprecated, please use a dtype torch.bool instead.
# /opt/conda/conda-bld/pytorch_1591914880026/work/aten/src/ATen/native/IndexingUtils.h:20: UserWarning: indexing with dtype torch.uint8 is now deprecated, please use a dtype torch.bool instead.
# /opt/conda/conda-bld/pytorch_1591914880026/work/aten/src/ATen/native/IndexingUtils.h:20: UserWarning: indexing with dtype torch.uint8 is now deprecated, please use a dtype torch.bool instead.

# %%
loss
# Out:
# tensor([517.1103], dtype=torch.float64, grad_fn=<UnsqueezeBackward0>)
